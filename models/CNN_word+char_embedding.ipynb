# %%
import tensorflow.keras as k
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split


import pandas as pd
import tensorflow as tf
import tensorflow.keras as k
import numpy as np

from sklearn.metrics import roc_curve, auc, precision_recall_fscore_support, accuracy_score
from matplotlib import pyplot as plt

pd.set_option('display.max_columns', None)  # show all columns
GPUs = tf.config.list_physical_devices('GPU')
if GPUs is None or len(GPUs) == 0:
    print("WARNING: No GPU, all there is is:")
    for device in tf.config.list_physical_devices():
        print(f'- {device}')
else:
    for gpu in GPUs:
        tf.config.experimental.set_memory_growth(gpu, True)
        print("Initialized", gpu)
# Out:
# WARNING: No GPU, all there is is:
# - PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')

# %%
def create_char_vectorizer(training_corpus):
    to_characters = k.preprocessing.text.Tokenizer(char_level=True, oov_token='<OOV>', filters='\t\n')
    to_characters.fit_on_texts(training_corpus)

    return to_characters


def create_word_vectorizer(training_corpus):
    word_vectorizer = CountVectorizer(
        stop_words=None,
        min_df=5,
        token_pattern=r'&\w+;|[:/&?=.\[\]\\]|%\w{2}|[-_\w\d]+',
        analyzer='word',
        max_features=500
    )
    word_vectorizer.fit(training_corpus)

    return word_vectorizer

def load_data(split_ratio=None, random_state=42):
    data = pd.read_csv("all_ita_final.csv")
    data = data.sample(frac=1, random_state=42).reset_index(drop=True)  # shuffle
    if split_ratio is None:
        data_train = data_validation = None
    else:
        data_train, data_validation = train_test_split(
            data,
            test_size=split_ratio,
            stratify=data['Label'],
            shuffle=True,
            random_state=42
        )

    return data_train, data_validation, data



data_train, data_validation, data = load_data(split_ratio=0.3, random_state=42)

# %%
word_vectorizer = create_word_vectorizer(data_train['Domain'])
char_vectorizer = create_char_vectorizer(data_train['Domain'])
LC = len(char_vectorizer.word_counts)
LW = len(word_vectorizer.vocabulary_)

print('Char vocab size:', LC)
print('Word vocab size:', LW)
# Out:
# Char vocab size: 49
# Word vocab size: 119

# %%
def postpad_to(sequence, to):
    return k.preprocessing.sequence.pad_sequences(sequence, to, padding='post', truncating='post')


def map_text(X):
    if X[-1] == '/':
        X = X[:-1]
    return X

def create_dataset_generator(word_vectorizer, char_vectorizer, data: pd.DataFrame, one_hot=False, vec_length=200):
    assert word_vectorizer is not None or char_vectorizer is not None

    if word_vectorizer is not None:
        word_tokenizer = word_vectorizer.build_tokenizer()

    def gen():
        for row in data.iterrows():
            out_dict = dict()

            url = row[1].Domain
            _type = row[1].Label
            if one_hot:
                target = tf.squeeze(tf.one_hot([_type], depth=2))
            else:
                target = tf.squeeze(_type)

            if word_vectorizer is not None:
                wv = tf.constant(postpad_to(
                    [[word_vectorizer.vocabulary_.get(a, -1) + 2 for a in word_tokenizer(url)]]  # 0 = padding, 1 = OOV
                    , vec_length), name='word')
                out_dict['word'] = tf.squeeze(wv)

            if char_vectorizer is not None:
                cv = tf.constant(postpad_to(char_vectorizer.texts_to_sequences([url]), vec_length), name='char')
                out_dict['char'] = tf.squeeze(cv)

            yield out_dict, target

    output_types, output_shapes = dict(), dict()
    if word_vectorizer is not None:
        output_types['word'] = tf.float64
        output_shapes['word'] = tf.TensorShape([vec_length])
    if char_vectorizer is not None:
        output_types['char'] = tf.float64
        output_shapes['char'] = tf.TensorShape([vec_length])

    ds = tf.data.Dataset.from_generator(
        gen,
        output_types=(output_types, tf.int32),
        output_shapes=(output_shapes, tf.TensorShape([] if not one_hot else [2]))
    )

    return ds

# %%
dataset_train = create_dataset_generator(word_vectorizer, char_vectorizer, data_train)\
    .shuffle(10000)\
    .prefetch(10000) #.batch(15*1024)
dataset_validation = create_dataset_generator(word_vectorizer, char_vectorizer, data_validation)\
    .shuffle(10000)\
    .prefetch(10000) #.batch(15*1024)

print('Train:', dataset_train.element_spec, '\nValid:', dataset_validation.element_spec)
# Out:
# Train: ({'word': TensorSpec(shape=(200,), dtype=tf.float64, name=None), 'char': TensorSpec(shape=(200,), dtype=tf.float64, name=None)}, TensorSpec(shape=(), dtype=tf.int32, name=None))
# Valid: ({'word': TensorSpec(shape=(200,), dtype=tf.float64, name=None), 'char': TensorSpec(shape=(200,), dtype=tf.float64, name=None)}, TensorSpec(shape=(), dtype=tf.int32, name=None))

# %%
def create_conv_subnet(input_layer, conv_kernel_sizes, prefix=''):
    convolutions = list()
    for kernel_size in conv_kernel_sizes:
        x = k.layers.Conv1D(
            filters=32,
            kernel_size=kernel_size,
            padding='same',
            activation='relu',
            name=f'{prefix}_conv_{kernel_size}'
        )(input_layer)
        x = k.layers.MaxPool1D()(x)
        convolutions.append(x)

    x = k.layers.concatenate(convolutions, axis=2)
    x = k.layers.Flatten()(x)
    return x

def create_url_net(input_length, emb_dim, conv_kernel_sizes):
    word_input = k.layers.Input(shape=[input_length], name='word')
    char_input = k.layers.Input(shape=[input_length], name='char')

    x = k.layers.concatenate([
        create_conv_subnet(
            k.layers.Embedding(2+LW, emb_dim, mask_zero=True)(word_input),
            conv_kernel_sizes,
            'word'
        ),
        create_conv_subnet(
            k.layers.Embedding(2+LC, emb_dim, mask_zero=True)(char_input),
            conv_kernel_sizes,
            'char'
        ),
    ])

    x = k.layers.Dropout(0.5, name=f'dropout')(x)
    x = k.layers.Dense(512, name=f'dense_1', activation='relu')(x)
    x = k.layers.Dense(128, activation='relu', name='dense_2')(x)
    x = k.layers.Dense(1, activation='sigmoid', name='dense_comb_out')(x)

    model = k.models.Model(inputs=[word_input, char_input], outputs=[x])
    return model

model = create_url_net(
    input_length=200,
    emb_dim=16,
    conv_kernel_sizes=[3,5]
)
model.compile(
    optimizer=k.optimizers.Adam(learning_rate=1e-4),
    loss='binary_crossentropy',
    metrics=['binary_accuracy']#, k.metrics.Precision(), k.metrics.Recall()]
)
#     loss='binary_crossentropy',
model.summary()
k.utils.plot_model(model, show_shapes=True)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  word (InputLayer)              [(None, 200)]        0           []
#
#  char (InputLayer)              [(None, 200)]        0           []
#
#  embedding (Embedding)          (None, 200, 16)      1936        ['word[0][0]']
#
#  embedding_1 (Embedding)        (None, 200, 16)      816         ['char[0][0]']
#
#  word_conv_3 (Conv1D)           (None, 200, 32)      1568        ['embedding[0][0]']
#
#  word_conv_5 (Conv1D)           (None, 200, 32)      2592        ['embedding[0][0]']
#
#  char_conv_3 (Conv1D)           (None, 200, 32)      1568        ['embedding_1[0][0]']
#
#  char_conv_5 (Conv1D)           (None, 200, 32)      2592        ['embedding_1[0][0]']
#
#  max_pooling1d (MaxPooling1D)   (None, 100, 32)      0           ['word_conv_3[0][0]']
#
#  max_pooling1d_1 (MaxPooling1D)  (None, 100, 32)     0           ['word_conv_5[0][0]']
#
#  max_pooling1d_2 (MaxPooling1D)  (None, 100, 32)     0           ['char_conv_3[0][0]']
#
#  max_pooling1d_3 (MaxPooling1D)  (None, 100, 32)     0           ['char_conv_5[0][0]']
#
#  concatenate (Concatenate)      (None, 100, 64)      0           ['max_pooling1d[0][0]',
#                                                                   'max_pooling1d_1[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 100, 64)      0           ['max_pooling1d_2[0][0]',
#                                                                   'max_pooling1d_3[0][0]']
#
#  flatten (Flatten)              (None, 6400)         0           ['concatenate[0][0]']
#
#  flatten_1 (Flatten)            (None, 6400)         0           ['concatenate_1[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 12800)        0           ['flatten[0][0]',
#                                                                   'flatten_1[0][0]']
#
#  dropout (Dropout)              (None, 12800)        0           ['concatenate_2[0][0]']
#
#  dense_1 (Dense)                (None, 512)          6554112     ['dropout[0][0]']
#
#  dense_2 (Dense)                (None, 128)          65664       ['dense_1[0][0]']
#
#  dense_comb_out (Dense)         (None, 1)            129         ['dense_2[0][0]']
#
# ==================================================================================================
# Total params: 6,630,977
# Trainable params: 6,630,977
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
bs=256

model.fit(
    dataset_train.batch(bs),
    epochs=10,
    validation_data=dataset_validation.batch(bs),
    callbacks=[
        k.callbacks.EarlyStopping(monitor='val_loss', patience=3),
        k.callbacks.ModelCheckpoint('./checkpoints', verbose=0)
    ],
)
# Out:
# Epoch 1/10
#      11/Unknown - 14s 662ms/step - loss: 0.6762 - binary_accuracy: 0.6560INFO:tensorflow:Assets written to: ./checkpoints/assets
# 11/11 [==============================] - 21s 1s/step - loss: 0.6762 - binary_accuracy: 0.6560 - val_loss: 0.6435 - val_binary_accuracy: 0.7458
# Epoch 2/10
# 11/11 [==============================] - ETA: 0s - loss: 0.6223 - binary_accuracy: 0.7497INFO:tensorflow:Assets written to: ./checkpoints/assets
# 11/11 [==============================] - 9s 712ms/step - loss: 0.6223 - binary_accuracy: 0.7497 - val_loss: 0.5784 - val_binary_accuracy: 0.7654
# Epoch 3/10
# 11/11 [==============================] - ETA: 0s - loss: 0.5550 - binary_accuracy: 0.7666INFO:tensorflow:Assets written to: ./checkpoints/assets
# 11/11 [==============================] - 9s 716ms/step - loss: 0.5550 - binary_accuracy: 0.7666 - val_loss: 0.5092 - val_binary_accuracy: 0.7823
# Epoch 4/10
# 11/11 [==============================] - ETA: 0s - loss: 0.4903 - binary_accuracy: 0.7930INFO:tensorflow:Assets written to: ./checkpoints/assets
# 11/11 [==============================] - 9s 708ms/step - loss: 0.4903 - binary_accuracy: 0.7930 - val_loss: 0.4484 - val_binary_accuracy: 0.8225
# Epoch 5/10
# 11/11 [==============================] - ETA: 0s - loss: 0.4230 - binary_accuracy: 0.8266INFO:tensorflow:Assets written to: ./checkpoints/assets
# 11/11 [==============================] - 10s 722ms/step - loss: 0.4230 - binary_accuracy: 0.8266 - val_loss: 0.3929 - val_binary_accuracy: 0.8528
# Epoch 6/10
# 11/11 [==============================] - ETA: 0s - loss: 0.3691 - binary_accuracy: 0.8576INFO:tensorflow:Assets written to: ./checkpoints/assets
# 11/11 [==============================] - 9s 709ms/step - loss: 0.3691 - binary_accuracy: 0.8576 - val_loss: 0.3368 - val_binary_accuracy: 0.8680
# Epoch 7/10
# 11/11 [==============================] - ETA: 0s - loss: 0.3194 - binary_accuracy: 0.8722INFO:tensorflow:Assets written to: ./checkpoints/assets
# 11/11 [==============================] - 9s 721ms/step - loss: 0.3194 - binary_accuracy: 0.8722 - val_loss: 0.2897 - val_binary_accuracy: 0.8947
# Epoch 8/10
# 11/11 [==============================] - ETA: 0s - loss: 0.2809 - binary_accuracy: 0.8902INFO:tensorflow:Assets written to: ./checkpoints/assets
# 11/11 [==============================] - 10s 738ms/step - loss: 0.2809 - binary_accuracy: 0.8902 - val_loss: 0.2637 - val_binary_accuracy: 0.8921
# Epoch 9/10
# 11/11 [==============================] - ETA: 0s - loss: 0.2505 - binary_accuracy: 0.9055INFO:tensorflow:Assets written to: ./checkpoints/assets
# 11/11 [==============================] - 10s 718ms/step - loss: 0.2505 - binary_accuracy: 0.9055 - val_loss: 0.2244 - val_binary_accuracy: 0.9260
# Epoch 10/10
# 11/11 [==============================] - ETA: 0s - loss: 0.2157 - binary_accuracy: 0.9192INFO:tensorflow:Assets written to: ./checkpoints/assets
# 11/11 [==============================] - 10s 751ms/step - loss: 0.2157 - binary_accuracy: 0.9192 - val_loss: 0.1994 - val_binary_accuracy: 0.9331

# %%
model.save('full_convolution_combined')
# Out:
# INFO:tensorflow:Assets written to: full_convolution_combined/assets

# %%
bs=256
model = k.models.load_model('full_convolution_combined')

# %%
X_validation, y_validation = np.array([*dataset_validation.as_numpy_iterator()]).T
# X_validation = np.array([item['word'] for item in X_validation])
# X_validation = np.array([item['char'] for item in X_validation])
X_validation = np.array([(item['word'],item['char']) for item in X_validation])
X_validation = tf.data.Dataset.from_tensor_slices(((X_validation[:,0,:], X_validation[:,1,:]), )).batch(bs)
y_validation = y_validation.astype('int32')

y_hat = model.predict(X_validation).ravel()

# %%
fpr, tpr, thresholds = roc_curve(y_validation, y_hat)
auc_ = auc(fpr, tpr)
best_threshold = thresholds[np.argmax(-fpr + tpr)]

# %%
model_name = "Fully Convolutional Combined"
model_full_name = "Fully Convolutional model with Word and Character Level Embedding"

plt.figure(1)
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr, tpr, label=f'{model_name} (area = {auc_:.3f})')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title(f'ROC curve for {model_full_name}')
plt.legend(loc='best')
plt.savefig(f'.{model_name.replace(" ", "_").lower()}_roc.pdf')
plt.show()

# %%
y_hat_01 = np.zeros_like(y_hat)
y_hat_01[y_hat >= best_threshold] = 1

np.unique(y_hat_01)
# Out:
# array([0., 1.], dtype=float32)

# %%
precision_recall_fscore_support(y_validation, y_hat_01, beta=1, average='binary'), \
    tpr[np.argmax(-fpr + tpr)], fpr[np.argmax(-fpr + tpr)], \
    accuracy_score(y_validation, y_hat_01)
# Out:
# ((0.9454545454545454, 0.9285714285714286, 0.9369369369369368, None),
#  0.9285714285714286,
#  0.053475935828877004,
#  0.9375557537912578)

# %%
plt.plot((-fpr + tpr) / 2, label='Sum')
plt.plot(tpr, label='TPR')
plt.plot(1-fpr, label='FPR')
plt.legend()

# %%
np.save("fpr_tpr/fccombi-fpr", fpr)
np.save("fpr_tpr/fccombi-tpr", tpr)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-16-aa7b0023475d> in <module>()
# ----> 1 np.save("fpr_tpr/fccombi-fpr", fpr)
#       2 np.save("fpr_tpr/fccombi-tpr", tpr)
#
# <__array_function__ internals> in save(*args, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/numpy/lib/npyio.py in save(file, arr, allow_pickle, fix_imports)
#     523         if not file.endswith('.npy'):
#     524             file = file + '.npy'
# --> 525         file_ctx = open(file, "wb")
#     526
#     527     with file_ctx as fid:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'fpr_tpr/fccombi-fpr.npy'
